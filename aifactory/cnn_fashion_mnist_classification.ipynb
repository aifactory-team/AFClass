# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# 패션아이템 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 9

# %% [markdown]
# 패션아이템 이미지와 라벨의 숫자가 의미하는 아이템 이름과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

labels = ['T-shirt/top',
          'Trouser',
          'Pullover',
          'Dress',
          'Coat',
          'Sandal',
          'Shirt',
          'Sneaker',
          'Bag',
          'Ankle boot']

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = labels[y_train[i]]
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 2차원(샘플수, 벡터수)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 1차원의 784개 벡터
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy
#
# 컨볼루션 신경망을 구성하기 위해, 컨볼루션 레이어, 맥스풀링 레이어, 플래튼 레이어를 사용하였습니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'),
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Flatten(), 
    Dense(512, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 38s 5ms/step - loss: 0.3881 - accuracy: 0.8585 - val_loss: 0.2661 - val_accuracy: 0.9005
# Epoch 2/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2381 - accuracy: 0.9118 - val_loss: 0.2490 - val_accuracy: 0.9070
# Epoch 3/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1906 - accuracy: 0.9286 - val_loss: 0.2279 - val_accuracy: 0.9161
# Epoch 4/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1547 - accuracy: 0.9415 - val_loss: 0.2125 - val_accuracy: 0.9251
# Epoch 5/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1203 - accuracy: 0.9552 - val_loss: 0.2439 - val_accuracy: 0.9189
# Epoch 6/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0924 - accuracy: 0.9653 - val_loss: 0.2592 - val_accuracy: 0.9177
# Epoch 7/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0689 - accuracy: 0.9742 - val_loss: 0.2651 - val_accuracy: 0.9204
# Epoch 8/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0520 - accuracy: 0.9813 - val_loss: 0.2866 - val_accuracy: 0.9252
# Epoch 9/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0442 - accuracy: 0.9840 - val_loss: 0.3587 - val_accuracy: 0.9209
# Epoch 10/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 0.3535 - val_accuracy: 0.9259
# Epoch 11/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0317 - accuracy: 0.9886 - val_loss: 0.3946 - val_accuracy: 0.9214
# Epoch 12/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0308 - accuracy: 0.9903 - val_loss: 0.4063 - val_accuracy: 0.9257
# Epoch 13/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 0.4511 - val_accuracy: 0.9225
# Epoch 14/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.5315 - val_accuracy: 0.9190
# Epoch 15/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.4861 - val_accuracy: 0.9210
# Epoch 16/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.5600 - val_accuracy: 0.9209
# Epoch 17/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.5130 - val_accuracy: 0.9239
# Epoch 18/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.5752 - val_accuracy: 0.9205
# Epoch 19/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.5712 - val_accuracy: 0.9197
# Epoch 20/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.6071 - val_accuracy: 0.9254
# Epoch 21/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.5116 - val_accuracy: 0.9255
# Epoch 22/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 0.5242 - val_accuracy: 0.9218
# Epoch 23/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.6135 - val_accuracy: 0.9243
# Epoch 24/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.6642 - val_accuracy: 0.9178
# Epoch 25/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.6667 - val_accuracy: 0.9217
# Epoch 26/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0206 - accuracy: 0.9942 - val_loss: 0.6320 - val_accuracy: 0.9216
# Epoch 27/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.6923 - val_accuracy: 0.9241
# Epoch 28/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0194 - accuracy: 0.9943 - val_loss: 0.6880 - val_accuracy: 0.9231
# Epoch 29/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.6827 - val_accuracy: 0.9190
# Epoch 30/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.6989 - val_accuracy: 0.9225
# Epoch 31/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.7411 - val_accuracy: 0.9202
# Epoch 32/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 0.7406 - val_accuracy: 0.9240
# Epoch 33/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.8040 - val_accuracy: 0.9188
# Epoch 34/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.7938 - val_accuracy: 0.9194
# Epoch 35/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 0.7711 - val_accuracy: 0.9205
# Epoch 36/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.8055 - val_accuracy: 0.9217
# Epoch 37/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.8046 - val_accuracy: 0.9207
# Epoch 38/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0171 - accuracy: 0.9956 - val_loss: 0.8657 - val_accuracy: 0.9204
# Epoch 39/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0185 - accuracy: 0.9951 - val_loss: 0.8119 - val_accuracy: 0.9212
# Epoch 40/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0175 - accuracy: 0.9959 - val_loss: 0.9292 - val_accuracy: 0.9209
# Epoch 41/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.8589 - val_accuracy: 0.9209
# Epoch 42/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0147 - accuracy: 0.9961 - val_loss: 0.8969 - val_accuracy: 0.9191
# Epoch 43/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0161 - accuracy: 0.9963 - val_loss: 1.0525 - val_accuracy: 0.9210
# Epoch 44/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0175 - accuracy: 0.9958 - val_loss: 0.8775 - val_accuracy: 0.9198
# Epoch 45/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 1.0440 - val_accuracy: 0.9212
# Epoch 46/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 1.1071 - val_accuracy: 0.9189
# Epoch 47/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 1.0017 - val_accuracy: 0.9225
# Epoch 48/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 1.0323 - val_accuracy: 0.9169
# Epoch 49/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 1.1229 - val_accuracy: 0.9197
# Epoch 50/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0170 - accuracy: 0.9958 - val_loss: 0.9550 - val_accuracy: 0.9238
# Epoch 51/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0147 - accuracy: 0.9968 - val_loss: 1.0048 - val_accuracy: 0.9204
# Epoch 52/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0126 - accuracy: 0.9967 - val_loss: 0.9799 - val_accuracy: 0.9223
# Epoch 53/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0169 - accuracy: 0.9960 - val_loss: 1.1834 - val_accuracy: 0.9212
# Epoch 54/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0186 - accuracy: 0.9959 - val_loss: 1.2907 - val_accuracy: 0.9201
# Epoch 55/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0180 - accuracy: 0.9962 - val_loss: 1.1333 - val_accuracy: 0.9250
# Epoch 56/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 1.3031 - val_accuracy: 0.9227
# Epoch 57/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0154 - accuracy: 0.9966 - val_loss: 1.3952 - val_accuracy: 0.9158
# Epoch 58/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0204 - accuracy: 0.9961 - val_loss: 1.2468 - val_accuracy: 0.9197
# Epoch 59/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0124 - accuracy: 0.9974 - val_loss: 1.1941 - val_accuracy: 0.9208
# Epoch 60/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0153 - accuracy: 0.9970 - val_loss: 1.3548 - val_accuracy: 0.9158
# Epoch 61/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0152 - accuracy: 0.9969 - val_loss: 1.2598 - val_accuracy: 0.9212
# Epoch 62/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0185 - accuracy: 0.9962 - val_loss: 1.4485 - val_accuracy: 0.9183
# Epoch 63/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0214 - accuracy: 0.9960 - val_loss: 1.4549 - val_accuracy: 0.9234
# Epoch 64/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0199 - accuracy: 0.9969 - val_loss: 1.2799 - val_accuracy: 0.9208
# Epoch 65/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0167 - accuracy: 0.9967 - val_loss: 1.2578 - val_accuracy: 0.9183
# Epoch 66/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0136 - accuracy: 0.9969 - val_loss: 1.2066 - val_accuracy: 0.9228
# Epoch 67/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 1.3245 - val_accuracy: 0.9179
# Epoch 68/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0180 - accuracy: 0.9967 - val_loss: 1.3386 - val_accuracy: 0.9175
# Epoch 69/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0148 - accuracy: 0.9969 - val_loss: 1.4247 - val_accuracy: 0.9222
# Epoch 70/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0145 - accuracy: 0.9973 - val_loss: 1.2890 - val_accuracy: 0.9202
# Epoch 71/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0203 - accuracy: 0.9962 - val_loss: 1.3574 - val_accuracy: 0.9227
# Epoch 72/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0129 - accuracy: 0.9977 - val_loss: 1.4654 - val_accuracy: 0.9208
# Epoch 73/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0200 - accuracy: 0.9964 - val_loss: 1.6316 - val_accuracy: 0.9224
# Epoch 74/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0146 - accuracy: 0.9974 - val_loss: 1.4816 - val_accuracy: 0.9237
# Epoch 75/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0190 - accuracy: 0.9968 - val_loss: 1.4744 - val_accuracy: 0.9252
# Epoch 76/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 1.6653 - val_accuracy: 0.9212
# Epoch 77/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0214 - accuracy: 0.9965 - val_loss: 1.6103 - val_accuracy: 0.9205
# Epoch 78/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0141 - accuracy: 0.9971 - val_loss: 1.7854 - val_accuracy: 0.9202
# Epoch 79/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0202 - accuracy: 0.9965 - val_loss: 1.6709 - val_accuracy: 0.9223
# Epoch 80/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0171 - accuracy: 0.9973 - val_loss: 1.7820 - val_accuracy: 0.9226
# Epoch 81/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0243 - accuracy: 0.9965 - val_loss: 1.8214 - val_accuracy: 0.9201
# Epoch 82/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 1.8154 - val_accuracy: 0.9235
# Epoch 83/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0130 - accuracy: 0.9977 - val_loss: 1.7924 - val_accuracy: 0.9236
# Epoch 84/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0226 - accuracy: 0.9969 - val_loss: 1.6979 - val_accuracy: 0.9209
# Epoch 85/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0191 - accuracy: 0.9969 - val_loss: 1.9646 - val_accuracy: 0.9170
# Epoch 86/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0131 - accuracy: 0.9978 - val_loss: 2.1228 - val_accuracy: 0.9224
# Epoch 87/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0165 - accuracy: 0.9974 - val_loss: 1.9975 - val_accuracy: 0.9186
# Epoch 88/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0250 - accuracy: 0.9966 - val_loss: 2.2126 - val_accuracy: 0.9177
# Epoch 89/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0167 - accuracy: 0.9977 - val_loss: 2.1258 - val_accuracy: 0.9219
# Epoch 90/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0218 - accuracy: 0.9970 - val_loss: 1.8322 - val_accuracy: 0.9244
# Epoch 91/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0226 - accuracy: 0.9971 - val_loss: 1.6309 - val_accuracy: 0.9181
# Epoch 92/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0169 - accuracy: 0.9976 - val_loss: 2.0529 - val_accuracy: 0.9229
# Epoch 93/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0191 - accuracy: 0.9971 - val_loss: 2.1319 - val_accuracy: 0.9202
# Epoch 94/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0207 - accuracy: 0.9970 - val_loss: 2.2223 - val_accuracy: 0.9222
# Epoch 95/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0219 - accuracy: 0.9970 - val_loss: 2.2943 - val_accuracy: 0.9217
# Epoch 96/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0156 - accuracy: 0.9974 - val_loss: 2.0554 - val_accuracy: 0.9187
# Epoch 97/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0174 - accuracy: 0.9974 - val_loss: 2.2883 - val_accuracy: 0.9221
# Epoch 98/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0156 - accuracy: 0.9979 - val_loss: 2.3070 - val_accuracy: 0.9211
# Epoch 99/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0205 - accuracy: 0.9972 - val_loss: 2.0485 - val_accuracy: 0.9228
# Epoch 100/100
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0213 - accuracy: 0.9971 - val_loss: 2.3739 - val_accuracy: 0.9212

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2163 - accuracy: 0.9210
# Test accuracy 0.9210000038146973
# Test loss 0.21634438633918762

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')

# %% [markdown]
# #### 실제로 사용해보기

# %%
def download_real_image(filename):
    url = 'https://github.com/aifactory-team/AFClass/blob/master/aifactory/warehouse/' + filename + '?raw=true' 
    urllib.request.urlretrieve(url, filename)

def predict_from_real_image(filename, invert):
    
    f, axarr = plt.subplots(2,2, subplot_kw={'xticks': [], 'yticks': []})
    
    img = Image.open(filename)
    axarr[0,0].imshow(img)
    axarr[0,0].set_title('orgin')

    img = img.resize((28, 28), Image.LANCZOS)
    axarr[0,1].imshow(img)
    axarr[0,1].set_title('resize')

    img = img.convert('L')
    axarr[1,0].imshow(img, cmap='gray')
    axarr[1,0].set_title('gray')

    img = np.array(img)
    if invert == True:
        img = 255.0 - img
        axarr[1,1].set_title('invert')
    else:
        axarr[1,1].set_title('no invert')
        
    axarr[1,1].imshow(img, cmap='gray')

    x_predict = img.reshape(1, 28, 28, 1).astype('float32') / 255.0
    y_predict = model.predict(x_predict)
    print(y_predict)
    print(labels[np.argmax(y_predict, axis=1)[0]])

# %%
download_real_image('fashion_item_1.png')
predict_from_real_image('fashion_item_1.png', invert = True)
# Out:
# [[1.92582243e-04 8.36736945e-06 1.08890570e-04 2.08216043e-05
#   1.17513184e-04 3.83580345e-06 2.39116998e-04 5.77956125e-05
#   9.99243736e-01 7.33068327e-06]]
# Bag

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=False)
# Out:
# [[7.4732904e-03 1.7133568e-04 1.9420192e-04 4.3542706e-05 4.6669262e-05
#   1.6586116e-04 2.4961848e-03 3.7308838e-04 9.8856419e-01 4.7157975e-04]]
# Bag

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=True)
# Out:
# [[4.6384092e-03 4.0850675e-05 5.8623943e-03 8.9210339e-02 8.7955004e-01
#   2.2546246e-05 2.0005936e-02 1.9660873e-05 6.1776431e-04 3.2147462e-05]]
# Coat

# %%
download_real_image('fashion_item_3.png')
predict_from_real_image('fashion_item_3.png', invert=True)
# Out:
# [[7.0755698e-02 2.5352836e-04 1.5924191e-03 7.0787421e-03 1.5602591e-04
#   2.7521642e-02 2.6573159e-03 1.2243092e-01 7.6304591e-01 4.5077833e-03]]
# Bag

# %%
download_real_image('fashion_item_4.png')
predict_from_real_image('fashion_item_4.png', invert=True)
# Out:
# [[1.8431845e-05 5.3172425e-06 2.5848738e-06 1.7552700e-05 7.5333278e-06
#   3.2379819e-05 2.0721118e-06 9.9053067e-01 2.6530556e-06 9.3807671e-03]]
# Sneaker
