# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# 패션아이템 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 9

# %% [markdown]
# 패션아이템 이미지와 라벨의 숫자가 의미하는 아이템 이름과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

labels = ['T-shirt/top',
          'Trouser',
          'Pullover',
          'Dress',
          'Coat',
          'Sandal',
          'Shirt',
          'Sneaker',
          'Bag',
          'Ankle boot']

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = labels[y_train[i]]
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 2차원(샘플수, 벡터수)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 1차원의 784개 벡터
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy

# %%
model = Sequential([
    Dense(64, input_dim=28*28, activation='relu'), 
    Dense(32, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 7s 2ms/step - loss: 0.5467 - accuracy: 0.8094 - val_loss: 0.4228 - val_accuracy: 0.8496
# Epoch 2/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4002 - accuracy: 0.8563 - val_loss: 0.4016 - val_accuracy: 0.8550
# Epoch 3/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3596 - accuracy: 0.8688 - val_loss: 0.3702 - val_accuracy: 0.8668
# Epoch 4/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3340 - accuracy: 0.8771 - val_loss: 0.3566 - val_accuracy: 0.8718
# Epoch 5/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3162 - accuracy: 0.8850 - val_loss: 0.3591 - val_accuracy: 0.8737
# Epoch 6/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2993 - accuracy: 0.8902 - val_loss: 0.3474 - val_accuracy: 0.8746
# Epoch 7/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2892 - accuracy: 0.8929 - val_loss: 0.3464 - val_accuracy: 0.8812
# Epoch 8/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2801 - accuracy: 0.8953 - val_loss: 0.3327 - val_accuracy: 0.8811
# Epoch 9/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2683 - accuracy: 0.8993 - val_loss: 0.3517 - val_accuracy: 0.8714
# Epoch 10/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2604 - accuracy: 0.9035 - val_loss: 0.3212 - val_accuracy: 0.8862
# Epoch 11/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2530 - accuracy: 0.9050 - val_loss: 0.3282 - val_accuracy: 0.8808
# Epoch 12/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2474 - accuracy: 0.9071 - val_loss: 0.3246 - val_accuracy: 0.8891
# Epoch 13/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2382 - accuracy: 0.9110 - val_loss: 0.3489 - val_accuracy: 0.8793
# Epoch 14/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2335 - accuracy: 0.9126 - val_loss: 0.3453 - val_accuracy: 0.8803
# Epoch 15/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2276 - accuracy: 0.9156 - val_loss: 0.3274 - val_accuracy: 0.8863
# Epoch 16/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2221 - accuracy: 0.9171 - val_loss: 0.3392 - val_accuracy: 0.8854
# Epoch 17/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2173 - accuracy: 0.9177 - val_loss: 0.3244 - val_accuracy: 0.8896
# Epoch 18/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2133 - accuracy: 0.9192 - val_loss: 0.3369 - val_accuracy: 0.8867
# Epoch 19/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2067 - accuracy: 0.9223 - val_loss: 0.3464 - val_accuracy: 0.8865
# Epoch 20/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2014 - accuracy: 0.9242 - val_loss: 0.3412 - val_accuracy: 0.8873
# Epoch 21/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1979 - accuracy: 0.9253 - val_loss: 0.3508 - val_accuracy: 0.8876
# Epoch 22/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1948 - accuracy: 0.9264 - val_loss: 0.3495 - val_accuracy: 0.8899
# Epoch 23/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1908 - accuracy: 0.9288 - val_loss: 0.3531 - val_accuracy: 0.8875
# Epoch 24/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1846 - accuracy: 0.9299 - val_loss: 0.3597 - val_accuracy: 0.8861
# Epoch 25/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1855 - accuracy: 0.9305 - val_loss: 0.3716 - val_accuracy: 0.8828
# Epoch 26/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1788 - accuracy: 0.9319 - val_loss: 0.3436 - val_accuracy: 0.8918
# Epoch 27/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1782 - accuracy: 0.9318 - val_loss: 0.3710 - val_accuracy: 0.8878
# Epoch 28/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1716 - accuracy: 0.9360 - val_loss: 0.3860 - val_accuracy: 0.8792
# Epoch 29/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1704 - accuracy: 0.9357 - val_loss: 0.3722 - val_accuracy: 0.8889
# Epoch 30/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1659 - accuracy: 0.9376 - val_loss: 0.3902 - val_accuracy: 0.8879
# Epoch 31/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1654 - accuracy: 0.9385 - val_loss: 0.3823 - val_accuracy: 0.8867
# Epoch 32/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1607 - accuracy: 0.9380 - val_loss: 0.3659 - val_accuracy: 0.8905
# Epoch 33/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1588 - accuracy: 0.9394 - val_loss: 0.4088 - val_accuracy: 0.8833
# Epoch 34/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1554 - accuracy: 0.9416 - val_loss: 0.3825 - val_accuracy: 0.8919
# Epoch 35/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1520 - accuracy: 0.9433 - val_loss: 0.3904 - val_accuracy: 0.8873
# Epoch 36/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1520 - accuracy: 0.9430 - val_loss: 0.4023 - val_accuracy: 0.8891
# Epoch 37/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1468 - accuracy: 0.9440 - val_loss: 0.4008 - val_accuracy: 0.8908
# Epoch 38/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1457 - accuracy: 0.9450 - val_loss: 0.4209 - val_accuracy: 0.8867
# Epoch 39/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1439 - accuracy: 0.9447 - val_loss: 0.4174 - val_accuracy: 0.8867
# Epoch 40/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1385 - accuracy: 0.9486 - val_loss: 0.4522 - val_accuracy: 0.8841
# Epoch 41/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1404 - accuracy: 0.9473 - val_loss: 0.4213 - val_accuracy: 0.8881
# Epoch 42/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1380 - accuracy: 0.9492 - val_loss: 0.4429 - val_accuracy: 0.8857
# Epoch 43/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1331 - accuracy: 0.9506 - val_loss: 0.4402 - val_accuracy: 0.8907
# Epoch 44/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1351 - accuracy: 0.9490 - val_loss: 0.4308 - val_accuracy: 0.8893
# Epoch 45/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1298 - accuracy: 0.9508 - val_loss: 0.4621 - val_accuracy: 0.8868
# Epoch 46/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1294 - accuracy: 0.9513 - val_loss: 0.4669 - val_accuracy: 0.8859
# Epoch 47/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1263 - accuracy: 0.9521 - val_loss: 0.4809 - val_accuracy: 0.8842
# Epoch 48/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1273 - accuracy: 0.9526 - val_loss: 0.4671 - val_accuracy: 0.8853
# Epoch 49/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1208 - accuracy: 0.9554 - val_loss: 0.4788 - val_accuracy: 0.8885
# Epoch 50/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1237 - accuracy: 0.9531 - val_loss: 0.4883 - val_accuracy: 0.8841
# Epoch 51/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1176 - accuracy: 0.9558 - val_loss: 0.4698 - val_accuracy: 0.8877
# Epoch 52/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1198 - accuracy: 0.9539 - val_loss: 0.4726 - val_accuracy: 0.8868
# Epoch 53/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1161 - accuracy: 0.9555 - val_loss: 0.4961 - val_accuracy: 0.8869
# Epoch 54/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1148 - accuracy: 0.9566 - val_loss: 0.4999 - val_accuracy: 0.8878
# Epoch 55/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1132 - accuracy: 0.9569 - val_loss: 0.4920 - val_accuracy: 0.8882
# Epoch 56/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1129 - accuracy: 0.9581 - val_loss: 0.5050 - val_accuracy: 0.8882
# Epoch 57/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1115 - accuracy: 0.9573 - val_loss: 0.5475 - val_accuracy: 0.8790
# Epoch 58/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1091 - accuracy: 0.9587 - val_loss: 0.4824 - val_accuracy: 0.8884
# Epoch 59/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1078 - accuracy: 0.9592 - val_loss: 0.5866 - val_accuracy: 0.8756
# Epoch 60/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1085 - accuracy: 0.9596 - val_loss: 0.5272 - val_accuracy: 0.8877
# Epoch 61/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1054 - accuracy: 0.9601 - val_loss: 0.5332 - val_accuracy: 0.8845
# Epoch 62/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1058 - accuracy: 0.9605 - val_loss: 0.5268 - val_accuracy: 0.8822
# Epoch 63/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1047 - accuracy: 0.9614 - val_loss: 0.5315 - val_accuracy: 0.8844
# Epoch 64/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1022 - accuracy: 0.9617 - val_loss: 0.5545 - val_accuracy: 0.8830
# Epoch 65/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1002 - accuracy: 0.9624 - val_loss: 0.5549 - val_accuracy: 0.8875
# Epoch 66/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0977 - accuracy: 0.9628 - val_loss: 0.5541 - val_accuracy: 0.8797
# Epoch 67/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1003 - accuracy: 0.9621 - val_loss: 0.5403 - val_accuracy: 0.8857
# Epoch 68/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0976 - accuracy: 0.9632 - val_loss: 0.5839 - val_accuracy: 0.8833
# Epoch 69/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0942 - accuracy: 0.9646 - val_loss: 0.5420 - val_accuracy: 0.8857
# Epoch 70/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0965 - accuracy: 0.9633 - val_loss: 0.5719 - val_accuracy: 0.8830
# Epoch 71/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0903 - accuracy: 0.9658 - val_loss: 0.5729 - val_accuracy: 0.8842
# Epoch 72/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0975 - accuracy: 0.9638 - val_loss: 0.6169 - val_accuracy: 0.8829
# Epoch 73/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0911 - accuracy: 0.9653 - val_loss: 0.6172 - val_accuracy: 0.8862
# Epoch 74/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0910 - accuracy: 0.9655 - val_loss: 0.6067 - val_accuracy: 0.8838
# Epoch 75/100
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0884 - accuracy: 0.9663 - val_loss: 0.6154 - val_accuracy: 0.8802
# Epoch 76/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0904 - accuracy: 0.9665 - val_loss: 0.6390 - val_accuracy: 0.8824
# Epoch 77/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0896 - accuracy: 0.9678 - val_loss: 0.6399 - val_accuracy: 0.8798
# Epoch 78/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0865 - accuracy: 0.9679 - val_loss: 0.6335 - val_accuracy: 0.8742
# Epoch 79/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0878 - accuracy: 0.9681 - val_loss: 0.6212 - val_accuracy: 0.8860
# Epoch 80/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0857 - accuracy: 0.9672 - val_loss: 0.6477 - val_accuracy: 0.8852
# Epoch 81/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0829 - accuracy: 0.9697 - val_loss: 0.6528 - val_accuracy: 0.8739
# Epoch 82/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0858 - accuracy: 0.9678 - val_loss: 0.6374 - val_accuracy: 0.8810
# Epoch 83/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0829 - accuracy: 0.9691 - val_loss: 0.6454 - val_accuracy: 0.8865
# Epoch 84/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0852 - accuracy: 0.9677 - val_loss: 0.6799 - val_accuracy: 0.8817
# Epoch 85/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0818 - accuracy: 0.9699 - val_loss: 0.6494 - val_accuracy: 0.8829
# Epoch 86/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0806 - accuracy: 0.9695 - val_loss: 0.6857 - val_accuracy: 0.8832
# Epoch 87/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0825 - accuracy: 0.9697 - val_loss: 0.6575 - val_accuracy: 0.8819
# Epoch 88/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0804 - accuracy: 0.9703 - val_loss: 0.6991 - val_accuracy: 0.8806
# Epoch 89/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0807 - accuracy: 0.9699 - val_loss: 0.6767 - val_accuracy: 0.8811
# Epoch 90/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0796 - accuracy: 0.9708 - val_loss: 0.6899 - val_accuracy: 0.8835
# Epoch 91/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0773 - accuracy: 0.9711 - val_loss: 0.6400 - val_accuracy: 0.8841
# Epoch 92/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0789 - accuracy: 0.9711 - val_loss: 0.6677 - val_accuracy: 0.8841
# Epoch 93/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0741 - accuracy: 0.9720 - val_loss: 0.6849 - val_accuracy: 0.8842
# Epoch 94/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0793 - accuracy: 0.9704 - val_loss: 0.7252 - val_accuracy: 0.8826
# Epoch 95/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0762 - accuracy: 0.9712 - val_loss: 0.7210 - val_accuracy: 0.8845
# Epoch 96/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0764 - accuracy: 0.9722 - val_loss: 0.7447 - val_accuracy: 0.8804
# Epoch 97/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0757 - accuracy: 0.9714 - val_loss: 0.7074 - val_accuracy: 0.8826
# Epoch 98/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0759 - accuracy: 0.9715 - val_loss: 0.7377 - val_accuracy: 0.8795
# Epoch 99/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0723 - accuracy: 0.9737 - val_loss: 0.7065 - val_accuracy: 0.8814
# Epoch 100/100
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0697 - accuracy: 0.9743 - val_loss: 0.7444 - val_accuracy: 0.8845

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3442 - accuracy: 0.8765
# Test accuracy 0.8765000104904175
# Test loss 0.3442241847515106

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')
